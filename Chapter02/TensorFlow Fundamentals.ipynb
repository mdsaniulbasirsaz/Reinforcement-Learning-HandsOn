# %%
import warnings

# %%
warnings.filterwarnings("ignore")
import tensorflow as tf

hello = tf.constant("Hello, TensorFlow!")
print(hello.numpy())
# Out:
# b'Hello, TensorFlow!'

# %%
weights = tf.Variable(tf.random.normal([3, 2], stddev=0.1), name="weights")

# %%
print(weights)
# Out:
# <tf.Variable 'weights:0' shape=(3, 2) dtype=float32, numpy=
# array([[-0.02383053,  0.00273317],
#        [ 0.18211496,  0.09339652],
#        [-0.06572157, -0.08831383]], dtype=float32)>

# %%
x = tf.constant(13)
x
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=13>

# %%
print(x.numpy())
# Out:
# 13

# %%
A = tf.multiply(8,5)
B = tf.multiply(A,1)

# %%
A = tf.multiply(8,5)
B = tf.multiply(4,3)

# %%
import tensorflow as tf
a = tf.constant(2,3)
print(a)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)

# %%
print(a.numpy())
# Out:
# 2
